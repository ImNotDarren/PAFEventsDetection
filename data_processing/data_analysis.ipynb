# %%
import wfdb
import os

# %%
record = wfdb.rdrecord('../../ECG Recordings/Training_set_I/data_32_22')
wfdb.plot_wfdb(record=record)
display(record.__dict__)
# Out:
# {'record_name': 'data_32_22',
#  'n_sig': 2,
#  'fs': 200,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 930582,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['paroxysmal atrial fibrillation'],
#  'sig_name': ['I', 'II'],
#  'p_signal': array([[5.00709449, 4.61705426],
#         [5.00007812, 4.55503876],
#         [5.00709449, 4.53705426],
#         ...,
#         [5.03012649, 4.63007752],
#         [4.98207961, 4.63705426],
#         [4.97201265, 4.6420155 ]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['data_32_22.dat', 'data_32_22.dat'],
#  'fmt': ['16', '16'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [None, None],
#  'adc_gain': [6556.097560975611, 6450.0],
#  'baseline': [-34111, -33025],
#  'units': ['mV', 'mV'],
#  'adc_res': [16, 16],
#  'adc_zero': [0, 0],
#  'init_value': [-1284, -3245],
#  'checksum': [54980, 9606],
#  'block_size': [0, 0]}

# %%
ann_ref = wfdb.rdann('../../ECG Recordings/Training_set_I/data_32_22', 'atr')

# %%
len(ann_ref.sample)
# Out:
# 4780

# %%
200 * 4780 - 930582
# Out:
# 25418

# %%
sig, fields = wfdb.rdsamp('../../ECG Recordings/Training_set_I/data_38_4')
fields
# Out:
# {'fs': 200,
#  'sig_len': 768863,
#  'n_sig': 2,
#  'base_date': None,
#  'base_time': None,
#  'units': ['mV', 'mV'],
#  'sig_name': ['I', 'II'],
#  'comments': ['persistent atrial fibrillation']}

# %%
# Out:
# {'fs': 200,
#  'sig_len': 99131,
#  'n_sig': 2,
#  'base_date': None,
#  'base_time': None,
#  'units': ['mV', 'mV'],
#  'sig_name': ['I', 'II'],
#  'comments': ['persistent atrial fibrillation']}

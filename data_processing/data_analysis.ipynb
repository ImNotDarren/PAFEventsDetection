# %%
import wfdb
import os

# %%
record = wfdb.rdrecord('../../ECG Recordings/Training_set_I/data_38_4')
wfdb.plot_wfdb(record=record)
display(record.__dict__)
# Out:
# {'record_name': 'data_38_4',
#  'n_sig': 2,
#  'fs': 200,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 768863,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['persistent atrial fibrillation'],
#  'sig_name': ['I', 'II'],
#  'p_signal': array([[4.64200506, 4.72207864],
#         [4.78708741, 4.85006354],
#         [4.79500754, 5.09712488],
#         ...,
#         [5.00507094, 4.83714627],
#         [5.01002102, 4.83506763],
#         [5.0150611 , 4.84011576]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['data_38_4.dat', 'data_38_4.dat'],
#  'fmt': ['16', '16'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [None, None],
#  'adc_gain': [11110.931435963777, 6735.169491525424],
#  'baseline': [-67122, -35946],
#  'units': ['mV', 'mV'],
#  'adc_res': [16, 16],
#  'adc_zero': [0, 0],
#  'init_value': [-15545, -4142],
#  'checksum': [35910, 5571],
#  'block_size': [0, 0]}

# %%
sig, fields = wfdb.rdsamp('../../ECG Recordings/Training_set_I/data_38_4')
fields
# Out:
# {'fs': 200,
#  'sig_len': 768863,
#  'n_sig': 2,
#  'base_date': None,
#  'base_time': None,
#  'units': ['mV', 'mV'],
#  'sig_name': ['I', 'II'],
#  'comments': ['persistent atrial fibrillation']}

# %%
# Out:
# {'fs': 200,
#  'sig_len': 99131,
#  'n_sig': 2,
#  'base_date': None,
#  'base_time': None,
#  'units': ['mV', 'mV'],
#  'sig_name': ['I', 'II'],
#  'comments': ['persistent atrial fibrillation']}
